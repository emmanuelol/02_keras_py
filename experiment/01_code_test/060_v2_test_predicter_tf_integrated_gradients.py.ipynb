# %%
# !pwd
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
import sys
sys.executable
# Out:
# /c/Users/81908/jupyter_notebook/tfgpu_py36_work/02_keras_py/experiment/01_code_test
# 'C:\\Users\\81908\\Anaconda3\\envs\\tfgpu\\python.exe'

# %% [markdown]
# # コードのテスト
# tf_integrated_gradients.py の関数について

# %%
import os
keras_py_path = r'C:\Users\81908\jupyter_notebook\tfgpu_py36_work\02_keras_py'
sys.path.append(keras_py_path)
from predicter import tf_integrated_gradients as integrated_gradients
output_dir = r'output_test\integrated_gradients'
os.makedirs(output_dir, exist_ok=True)

# %%
# imagenetのXceptionで犬猫画像についてintegrated_gradients実行
img_path = 'cat_dog.png'
integrated_gradients.main(img_path=img_path, 
                          output_dir=output_dir)
# Out:
# Predicted: tf.Tensor(243, shape=(), dtype=int64) bull_mastiff

# %%
# 画像指定してimagenetのXceptionでintegrated_gradients実行
img_path = r'D:\iPhone_pictures\2019-09\IMG_1380.PNG'
integrated_gradients.main(img_path=img_path, 
                          output_dir=output_dir)
# Out:
# Predicted: tf.Tensor(917, shape=(), dtype=int64) comic_book

# %%
# idと画像指定してimagenetのXceptionでintegrated_gradients実行
img_path = r'D:\iPhone_pictures\2019-09\IMG_1380.PNG'
class_idx = 445  # bikini
integrated_gradients.main(img_path=img_path, 
                          class_idx=class_idx, 
                          output_dir=output_dir)
# Out:
# Predicted: 445 bikini

# %%
# 勾配だけ可視化
img_path = r'D:\iPhone_pictures\2019-09\IMG_1380.PNG'
class_idx = 445  # bikini
overlay = False
integrated_gradients.main(img_path=img_path, 
                          class_idx=class_idx, 
                          output_dir=output_dir,
                          overlay=overlay)
# Out:
# Predicted: 445 bikini

# %%
# モデル、id、画像指定してintegrated_gradients実行
img_path = r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\output_new\dataset\all\test\2\1332_2002-04-02_2002-07-25.png'
model_path = r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\output_new\model\tf_base_class_all_py\best_val_accuracy.h5'
overlay = False
for class_idx in [0, 1, 2]:
    integrated_gradients.main(img_path=img_path,  
                              class_idx=class_idx, 
                              model_path=model_path, 
                              output_dir=output_dir, 
                              overlay=overlay)
# Out:
# Predicted: 0 0
# Predicted: 1 1
# Predicted: 2 2

# %%
# integrated_gradientsのみ実行
img_path = r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\output_new\dataset\all\test\2\1332_2002-04-02_2002-07-25.png'
model_path = r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\output_new\model\tf_base_class_all_py\best_val_accuracy.h5'
figsize=(8, 8)
is_igrad_image_only = True
for class_idx in [0, 1, 2]:
    integrated_gradients.main(img_path=img_path, 
                              class_idx=class_idx, 
                              model_path=model_path, 
                              output_dir=output_dir, 
                              figsize=figsize, 
                              is_igrad_image_only=is_igrad_image_only)
# Out:
# Predicted: 0 0
# Predicted: 1 1
# Predicted: 2 2

# %%
# 普通のgradientsのみ実行
img_path = r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\output_new\dataset\all\test\2\1332_2002-04-02_2002-07-25.png'
model_path = r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\output_new\model\tf_base_class_all_py\best_val_accuracy.h5'
figsize=(8, 8)
is_grad_image_only = True
overlay = False
for class_idx in [0, 1, 2]:
    integrated_gradients.main(img_path=img_path, 
                              class_idx=class_idx, 
                              model_path=model_path, 
                              output_dir=output_dir, 
                              figsize=figsize, 
                              is_grad_image_only=is_grad_image_only)
# Out:
# Predicted: 0 0
# Predicted: 1 1
# Predicted: 2 2

# %% [markdown]
# ## imagenetのラベル確認

# %%
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50, decode_predictions
from tensorflow.keras import backend as K
K.set_learning_phase(0)

model = ResNet50()
model.name
# Out:
# 'resnet50'

# %%
for i, idx in enumerate(range(1000)):
    print(i, decode_predictions(np.eye(1, 1000, idx))[0][0][1])
# Out:
# 0 tench
# 1 goldfish
# 2 great_white_shark
# 3 tiger_shark
# 4 hammerhead
# 5 electric_ray
# 6 stingray
# 7 cock
# 8 hen
# 9 ostrich
# 10 brambling
# 11 goldfinch
# 12 house_finch
# 13 junco
# 14 indigo_bunting
# 15 robin
# 16 bulbul
# 17 jay
# 18 magpie
# 19 chickadee
# 20 water_ouzel
# 21 kite
# 22 bald_eagle
# 23 vulture
# 24 great_grey_owl
# 25 European_fire_salamander
# 26 common_newt
# 27 eft
# 28 spotted_salamander
# 29 axolotl
# 30 bullfrog
# 31 tree_frog
# 32 tailed_frog
# 33 loggerhead
# 34 leatherback_turtle
# 35 mud_turtle
# 36 terrapin
# 37 box_turtle
# 38 banded_gecko
# 39 common_iguana
# 40 American_chameleon
# 41 whiptail
# 42 agama
# 43 frilled_lizard
# 44 alligator_lizard
# 45 Gila_monster
# 46 green_lizard
# 47 African_chameleon
# 48 Komodo_dragon
# 49 African_crocodile
# 50 American_alligator
# 51 triceratops
# 52 thunder_snake
# 53 ringneck_snake
# 54 hognose_snake
# 55 green_snake
# 56 king_snake
# 57 garter_snake
# 58 water_snake
# 59 vine_snake
# ...
