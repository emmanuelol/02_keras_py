# %% [markdown]
# # コードのテスト
# ## modelの学習関連の関数について

# %%
import os
gpu_num = "0"
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_num)

# モジュールimport
import os, sys
current_dir = os.path.dirname(os.path.abspath("__file__"))
path = os.path.join(current_dir, '../../')
sys.path.append(path)
from dataset import plot_log, prepare_data, util, plot_12task_log
from transformer import get_train_valid_test
from model import define_model, multi_loss, my_callback, my_metric
from predicter import roc_curve, conf_matrix, multi_predict, grad_cam

import numpy as np
import keras
import keras.backend as K
import matplotlib.pyplot as plt

sys.path.append(r'/home/tmp10014/jupyterhub/notebook/other/lib_DL/mixup-generator')
from random_eraser import get_random_eraser
# Out:
# plot_log.py: loaded as module file
# prepare_data.py: loaded as module file
# util.py: loaded as module file
# plot_12task_log.py: loaded as module file
# Using TensorFlow backend.
# /home/tmp10014/.conda/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# get_train_valid_test.py: loaded as module file
# define_model.py: loaded as module file
# multi_loss.py: loaded as module file
# my_callback.py: loaded as module file
# my_metric.py: loaded as module file
# roc_curve.py: loaded as module file
# conf_matrix.py: loaded as module file
# multi_predict.py: loaded as module file
# grad_cam.py: loaded as module file

# %%
# %%time
num_classes=12
train_batch_size=68#17
valid_batch_size=37#6
shape=[100, 100, 3]
epochs=3
out_dir='output_test/100x100'
gpu_count=len(gpu_num.split(','))

# ラベル情報などが書いたcsvファイル（tox21_compoundData.csv）
csv_path = r'../../storage/tox21_compoundData.csv'
# IDにファイルのフルパスつける
img_dir = r'../../storage/img/Wash/100x100/'
# 画像ファイルのサフィックス
img_suffix = r'_000.jpg'
# 欠損値を-1に置換したtox21_compoundData.csvのデータフレーム
df = prepare_data.make_label_df(csv_path, img_dir, img_suffix=img_suffix)
# Tox21の画像のパスとラベル(y_train,y_valid,y_test)を取得する
train_files, validation_files, test_files, y_train, y_valid, y_test = prepare_data.make_train_val_test(df)

horizontal_flip=True
vertical_flip=True
rotation_range=60
zoom_range=[0.5, 1.9]
shear_range=0.2

d_cls = get_train_valid_test.LabeledDataset(shape, train_batch_size, valid_batch_size)
d_cls.load_train_as_image(train_files, y_train)
d_cls.load_validation_as_image(validation_files, y_valid)
d_cls.load_test_as_image(test_files, y_test)

# ImageDataGenerator のオプションを辞書型で詰める
# get_random_eraserでd_clsの値使うのでここで宣言しないとエラーになる
IDG_options={'horizontal_flip': horizontal_flip
             , 'vertical_flip': vertical_flip
             , 'rotation_range': rotation_range
             , 'zoom_range': zoom_range
             , 'shear_range': shear_range
             , 'preprocessing_function': get_random_eraser(v_l=np.min(d_cls.X_train), v_h=np.max(d_cls.X_train))
            }

d_cls.create_generator(IDG_options=IDG_options)

# 12の出力（task）をだすgeneratorにする
generator_multi_train = get_train_valid_test.generator_12output(d_cls.train_gen)
generator_multi_valid = get_train_valid_test.generator_12output(d_cls.valid_gen)
# Out:
# training_set_y.shape: (11764, 12)
# validation_set_y.shape: (296, 12)
# test_set_y.shape: (647, 12)
# ----- train_ImageDataGenerator -----
# use_mixup: False
# IDG_options: {'horizontal_flip': True, 'vertical_flip': True, 'rotation_range': 60, 'zoom_range': [0.5, 1.9], 'shear_range': 0.2, 'preprocessing_function': <function get_random_eraser.<locals>.eraser at 0x7f32af0050d0>}
# CPU times: user 7.83 s, sys: 2.61 s, total: 10.4 s
# Wall time: 26.8 s

# %% [markdown]
# ## model.fit_generator(No_branch)
# ## my_callback.LossHistory
# ## my_callback.cosine_annealing

# %%
# callback
check_monitor='val_loss' # val_loss最少になるモデルを保存する
early_monitor='val_loss' # val_lossが100エポック更新されなければ学習停止する
early_stopping_pati=100
plateau_monitor='val_loss' # val_lossが100エポック更新されなければ学習率0.9倍
plateau_pati=100
plateau_factor=0.9 # plateau_factor=1.0 はエラーになる

cb = []
if gpu_count > 1:
    # マルチGPUでModelCheckpoint使うためのコールバック
    weight_dir = os.path.join(out_dir, 'model_weight')
    os.makedirs(weight_dir, exist_ok=True)
    cb.append(my_callback.MyCheckPoint(orig_model, weight_dir))
    
    # batch_sizeは並列で処理を行うために元々のbatch_sizeをGPUの数だけ掛ける
    train_batch_size = train_batch_size * gpu_count
    valid_batch_size = valid_batch_size * gpu_count
else:
    cb.append(keras.callbacks.TerminateOnNaN())
    #cb.append(keras.callbacks.ModelCheckpoint(filepath=os.path.join(out_dir, 'test_model.h5'), monitor=check_monitor, save_best_only=True, verbose=1))#, monitor='val_acc'
    cb.append(keras.callbacks.EarlyStopping(monitor=early_monitor, patience=early_stopping_pati, verbose=1))
    # ReduceLROnPlateau つけないと学習率csvファイルに記録されない
    plateau = keras.callbacks.ReduceLROnPlateau(
                monitor=plateau_monitor, # モデルの検証データセットでの損失値を監視
                factor=plateau_factor, # コールバックが起動したら学習率をplateau_factor掛ける
                patience=plateau_pati # 検証データでの損失値がplateauエポックにわたって改善しなかった場合はコールバックを起動
                )
    cb.append(plateau)
    
    base_lr = 0.1 * train_batch_size / 128  # adamとかなら1e-3くらい。SGDなら例えば 0.1 * batch_size / 128 とかくらい。nadamなら0.002*10 ?
    lr_decay_rate = 1 / 3
    lr_steps = 4
    cb.append(keras.callbacks.LearningRateScheduler(lambda ep: float(base_lr * lr_decay_rate ** (ep * lr_steps // epochs))))
    
    # 学習率をエポック増やすごとにコサインカーブのように上げ下げする
    ## 引数なしならlr*0.01されるだけ
    cb.append(my_callback.cosine_annealing())
    
    # callbackで学習率表示
    loss_history = my_callback.LossHistory()
    cb.append(loss_history)
    
cb.append(keras.callbacks.CSVLogger(os.path.join(out_dir, 'history.tsv'), separator='\t'))
print(cb)
# Out:
# [<keras.callbacks.TerminateOnNaN object at 0x7f32aed10278>, <keras.callbacks.EarlyStopping object at 0x7f32aed102e8>, <keras.callbacks.ReduceLROnPlateau object at 0x7f32aed10320>, <keras.callbacks.LearningRateScheduler object at 0x7f32aed10358>, <model.my_callback.cosine_annealing.<locals>._CosineAnnealing object at 0x7f32aed10390>, <model.my_callback.LossHistory object at 0x7f32aed103c8>, <keras.callbacks.CSVLogger object at 0x7f32aed10438>]

# %%
# %%time
choice_model_list=['NASNetLarge', 'SEInceptionResNetV2']# ['VGG16','ResNet50','InceptionV3','Xception','InceptionResNetV2','NASNetLarge','SEResNet154','SEInceptionV3','SEInceptionResNetV2']
FCnum_list=[1,4]# [None,1,2,3,4,5]
FCpool='GlobalAveragePooling2D'
Dence_1, Dropout_1, addBatchNorm_1, kernel_initializer_1, l2_rate_1=1024, 0.5, None, 'he_normal', 1e-4
Dence_2, Dropout_2, addBatchNorm_2, kernel_initializer_2, l2_rate_2=512, 0.5, None, 'he_normal', 1e-4
Dence_3, Dropout_3, addBatchNorm_3, kernel_initializer_3, l2_rate_3=256, 0.5, None, 'he_normal', 1e-4
Dence_4, Dropout_4, addBatchNorm_4, kernel_initializer_4, l2_rate_4=128, 0.5, None, 'he_normal', 1e-4
Dence_5, Dropout_5, addBatchNorm_5, kernel_initializer_5, l2_rate_5=64, 0.5, None, 'he_normal', 1e-4
pred_kernel_initializer='zeros'
pred_l2_rate=1e-4
activation_list=['sigmoid']# ['sigmoid','softmax']
trainable='all'
skip_bn=True
opt_list=['sgd']# ['sgd', 'rmsprop', 'adagrad', 'adadelta', 'adam', 'adamax', 'nadam']

for choice_model in choice_model_list:
    for FCnum in FCnum_list:
        for activation in activation_list:
            print('\n###################################')
            model, orig_model = define_model.get_fine_tuning_model(out_dir, shape[0], shape[1], shape[2], num_classes
                                                                    , choice_model, trainable
                                                                    , FCnum
                                                                    , FCpool=FCpool
                                                                    , Dence_1=Dence_1, Dropout_1=Dropout_1, addBatchNorm_1=addBatchNorm_1, kernel_initializer_1=kernel_initializer_1, l2_rate_1=l2_rate_1
                                                                    , Dence_2=Dence_2, Dropout_2=Dropout_2, addBatchNorm_2=addBatchNorm_2, kernel_initializer_2=kernel_initializer_2, l2_rate_2=l2_rate_2
                                                                    , Dence_3=Dence_3, Dropout_3=Dropout_3, addBatchNorm_3=addBatchNorm_3, kernel_initializer_3=kernel_initializer_3, l2_rate_3=l2_rate_3
                                                                    , Dence_4=Dence_4, Dropout_4=Dropout_4, addBatchNorm_4=addBatchNorm_4, kernel_initializer_4=kernel_initializer_4, l2_rate_4=l2_rate_4
                                                                    , Dence_5=Dence_5, Dropout_5=Dropout_5, addBatchNorm_5=addBatchNorm_5, kernel_initializer_5=kernel_initializer_5, l2_rate_5=l2_rate_5
                                                                    , pred_kernel_initializer=pred_kernel_initializer, pred_l2_rate=pred_l2_rate
                                                                    , activation=activation 
                                                                    , gpu_count=gpu_count
                                                                    , skip_bn=skip_bn
                                                                  )
            for opt in opt_list:
                # オプティマイザ
                optim = define_model.get_optimizers(opt, decay=0.0)
                lr_metric = my_metric.get_lr_metric(optim)# コールバックで下げたlrは表示されない。あくまでそのエポックの初期学習率をエポックごとに表示する
                # モデルコンパイル
                model.compile(loss=multi_loss.build_masked_loss(K.binary_crossentropy)
                              , optimizer=optim
                              , metrics=['accuracy', 'binary_accuracy', multi_loss.masked_accuracy, lr_metric])
                
            model.fit_generator(d_cls.train_gen
                    , steps_per_epoch=d_cls.train_steps_per_epoch()
                    , epochs=epochs
                    , validation_data=d_cls.valid_gen
                    , validation_steps=d_cls.valid_steps_per_epoch()
                    , callbacks=cb
                    , verbose=1)
# Out:
# ###################################
# ----- model_param -----
# output_dir = output_test/100x100
# img_rows img_cols channels = 100 100 3
# num_classes = 12
# choice_model trainable = NASNetLarge all
# FCnum = 1
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# ---- choice_optim = sgd ----
# sgd_lr sgd_momentum sgd_decay sgd_nesterov = 0.01 0.9 0.0 True
# Epoch 1/3
# 172/173 [============================>.] - ETA: 2s - loss: 1.6783 - acc: 0.1353 - binary_accuracy: 0.6464 - masked_accuracy: 0.9270 - lr: 0.0075
# lr: 0.1
# 173/173 [==============================] - 372s 2s/step - loss: 1.6776 - acc: 0.1353 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 0.0075 - val_loss: 1.8233 - val_acc: 0.0574 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0075
# Epoch 2/3
# 172/173 [============================>.] - ETA: 2s - loss: 1.6199 - acc: 0.1279 - binary_accuracy: 0.6462 - masked_accuracy: 0.9273 - lr: 0.0026
# lr: 0.1
# 173/173 [==============================] - 354s 2s/step - loss: 1.6199 - acc: 0.1277 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 0.0026 - val_loss: 1.8214 - val_acc: 0.0709 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0026
# Epoch 3/3
# 172/173 [============================>.] - ETA: 2s - loss: 1.6177 - acc: 0.1648 - binary_accuracy: 0.6459 - masked_accuracy: 0.9272 - lr: 1.0000e-04
# lr: 0.1
# 173/173 [==============================] - 354s 2s/step - loss: 1.6176 - acc: 0.1649 - binary_accuracy: 0.6461 - masked_accuracy: 0.9273 - lr: 1.0000e-04 - val_loss: 1.8254 - val_acc: 0.0709 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 1.0000e-04
#
# ###################################
# ----- model_param -----
# output_dir = output_test/100x100
# img_rows img_cols channels = 100 100 3
# num_classes = 12
# choice_model trainable = NASNetLarge all
# FCnum = 4
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# ---- choice_optim = sgd ----
# sgd_lr sgd_momentum sgd_decay sgd_nesterov = 0.01 0.9 0.0 True
# Epoch 1/3
# 172/173 [============================>.] - ETA: 2s - loss: 1.8346 - acc: 0.1148 - binary_accuracy: 0.6459 - masked_accuracy: 0.9272 - lr: 0.0075
# lr: 0.1
# 173/173 [==============================] - 373s 2s/step - loss: 1.8344 - acc: 0.1150 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 0.0075 - val_loss: 2.0054 - val_acc: 0.0574 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0075
# Epoch 2/3
# 172/173 [============================>.] - ETA: 2s - loss: 1.7644 - acc: 0.1031 - binary_accuracy: 0.6459 - masked_accuracy: 0.9272 - lr: 0.0026
# lr: 0.1
# 173/173 [==============================] - 354s 2s/step - loss: 1.7644 - acc: 0.1033 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 0.0026 - val_loss: 1.9902 - val_acc: 0.0574 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0026
# Epoch 3/3
# 172/173 [============================>.] - ETA: 2s - loss: 1.7636 - acc: 0.1713 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 1.0000e-04
# lr: 0.1
# 173/173 [==============================] - 354s 2s/step - loss: 1.7634 - acc: 0.1710 - binary_accuracy: 0.6461 - masked_accuracy: 0.9273 - lr: 1.0000e-04 - val_loss: 1.9952 - val_acc: 0.0574 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 1.0000e-04
#
# ###################################
# ----- model_param -----
# output_dir = output_test/100x100
# img_rows img_cols channels = 100 100 3
# num_classes = 12
# choice_model trainable = SEInceptionResNetV2 all
# FCnum = 1
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# ---- choice_optim = sgd ----
# sgd_lr sgd_momentum sgd_decay sgd_nesterov = 0.01 0.9 0.0 True
# Epoch 1/3
# 172/173 [============================>.] - ETA: 0s - loss: 0.4010 - acc: 0.0852 - binary_accuracy: 0.6462 - masked_accuracy: 0.9271 - lr: 0.0075
# lr: 0.1
# 173/173 [==============================] - 157s 910ms/step - loss: 0.4006 - acc: 0.0857 - binary_accuracy: 0.6461 - masked_accuracy: 0.9271 - lr: 0.0075 - val_loss: 1.3242 - val_acc: 0.6655 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0075
# Epoch 2/3
# 172/173 [============================>.] - ETA: 0s - loss: 0.3337 - acc: 0.0979 - binary_accuracy: 0.6461 - masked_accuracy: 0.9271 - lr: 0.0026
# lr: 0.1
# 173/173 [==============================] - 144s 835ms/step - loss: 0.3338 - acc: 0.0976 - binary_accuracy: 0.6461 - masked_accuracy: 0.9270 - lr: 0.0026 - val_loss: 1.3239 - val_acc: 0.0574 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0026
# Epoch 3/3
# 172/173 [============================>.] - ETA: 0s - loss: 0.3326 - acc: 0.0368 - binary_accuracy: 0.6458 - masked_accuracy: 0.9274 - lr: 1.0000e-04
# lr: 0.1
# 173/173 [==============================] - 144s 835ms/step - loss: 0.3329 - acc: 0.0366 - binary_accuracy: 0.6461 - masked_accuracy: 0.9273 - lr: 1.0000e-04 - val_loss: 0.3967 - val_acc: 0.0473 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 1.0000e-04
#
# ###################################
# ----- model_param -----
# output_dir = output_test/100x100
# img_rows img_cols channels = 100 100 3
# num_classes = 12
# choice_model trainable = SEInceptionResNetV2 all
# FCnum = 4
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# ---- choice_optim = sgd ----
# sgd_lr sgd_momentum sgd_decay sgd_nesterov = 0.01 0.9 0.0 True
# Epoch 1/3
# 172/173 [============================>.] - ETA: 0s - loss: 0.5696 - acc: 0.1056 - binary_accuracy: 0.6462 - masked_accuracy: 0.9273 - lr: 0.0075
# lr: 0.1
# 173/173 [==============================] - 158s 912ms/step - loss: 0.5693 - acc: 0.1053 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 0.0075 - val_loss: 1.4623 - val_acc: 0.6655 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0075
# Epoch 2/3
# 172/173 [============================>.] - ETA: 0s - loss: 0.4804 - acc: 0.0629 - binary_accuracy: 0.6458 - masked_accuracy: 0.9273 - lr: 0.0026
# lr: 0.1
# 173/173 [==============================] - 145s 841ms/step - loss: 0.4806 - acc: 0.0634 - binary_accuracy: 0.6461 - masked_accuracy: 0.9272 - lr: 0.0026 - val_loss: 1.4618 - val_acc: 0.6655 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 0.0026
# Epoch 3/3
# 172/173 [============================>.] - ETA: 0s - loss: 0.4782 - acc: 0.0867 - binary_accuracy: 0.6463 - masked_accuracy: 0.9273 - lr: 1.0000e-04
# lr: 0.1
# 173/173 [==============================] - 146s 844ms/step - loss: 0.4782 - acc: 0.0868 - binary_accuracy: 0.6461 - masked_accuracy: 0.9273 - lr: 1.0000e-04 - val_loss: 0.5366 - val_acc: 0.0473 - val_binary_accuracy: 0.8088 - val_masked_accuracy: 0.9178 - val_lr: 1.0000e-04
# CPU times: user 1h 9min, sys: 4min 59s, total: 1h 13min 59s
# Wall time: 56min 16s

# %%
# %matplotlib inline
plot_log.plot_results(out_dir, os.path.join(out_dir, 'history.tsv'))

# %% [markdown]
# ## model.fit_generator(12branch)
# - ニューラルネットワークを分岐させてMulti-task learningのときに使うもの
#
# ## my_callback.LossHistory
# ## my_callback.cosine_annealing

# %%
# callback
check_monitor='val_loss' # val_loss最少になるモデルを保存する
early_monitor='val_loss' # val_lossが100エポック更新されなければ学習停止する
early_stopping_pati=100
plateau_monitor='val_loss' # val_lossが100エポック更新されなければ学習率0.9倍
plateau_pati=100
plateau_factor=0.9 # plateau_factor=1.0 はエラーになる

cb = []
if gpu_count > 1:
    # マルチGPUでModelCheckpoint使うためのコールバック
    weight_dir = os.path.join(out_dir, 'model_weight')
    os.makedirs(weight_dir, exist_ok=True)
    cb.append(my_callback.MyCheckPoint(orig_model, weight_dir))
    
    # batch_sizeは並列で処理を行うために元々のbatch_sizeをGPUの数だけ掛ける
    train_batch_size = train_batch_size * gpu_count
    valid_batch_size = valid_batch_size * gpu_count
else:
    cb.append(keras.callbacks.TerminateOnNaN())
    #cb.append(keras.callbacks.ModelCheckpoint(filepath=os.path.join(out_dir, 'test_model.h5'), monitor=check_monitor, save_best_only=True, verbose=1))#, monitor='val_acc'
    cb.append(keras.callbacks.EarlyStopping(monitor=early_monitor, patience=early_stopping_pati, verbose=1))
    # ReduceLROnPlateau つけないと学習率csvファイルに記録されない
    plateau = keras.callbacks.ReduceLROnPlateau(
                monitor=plateau_monitor, # モデルの検証データセットでの損失値を監視
                factor=plateau_factor, # コールバックが起動したら学習率をplateau_factor掛ける
                patience=plateau_pati # 検証データでの損失値がplateauエポックにわたって改善しなかった場合はコールバックを起動
                )
    cb.append(plateau)
    
    base_lr = 0.1 * train_batch_size / 128  # adamとかなら1e-3くらい。SGDなら例えば 0.1 * batch_size / 128 とかくらい。nadamなら0.002*10 ?
    lr_decay_rate = 1 / 3
    lr_steps = 4
    cb.append(keras.callbacks.LearningRateScheduler(lambda ep: float(base_lr * lr_decay_rate ** (ep * lr_steps // epochs))))
    
    # 学習率をエポック増やすごとにコサインカーブのように上げ下げする
    ## 引数なしならlr*0.01されるだけ
    cb.append(my_callback.cosine_annealing())
    
    # callbackで学習率表示
    loss_history = my_callback.LossHistory()
    cb.append(loss_history)
    
cb.append(keras.callbacks.CSVLogger(os.path.join(out_dir, 'history.tsv'), separator='\t'))
print(cb)
# Out:
# [<keras.callbacks.TerminateOnNaN object at 0x7f32aed102e8>, <keras.callbacks.EarlyStopping object at 0x7f32aed10358>, <keras.callbacks.ReduceLROnPlateau object at 0x7f32aed10390>, <keras.callbacks.LearningRateScheduler object at 0x7f32aed10438>, <model.my_callback.cosine_annealing.<locals>._CosineAnnealing object at 0x7f3115b2ab70>, <model.my_callback.LossHistory object at 0x7f3123f475f8>, <keras.callbacks.CSVLogger object at 0x7f3115ac0278>]

# %%
# %%time
cb.append(keras.callbacks.ModelCheckpoint(filepath=os.path.join(out_dir, 'test_model_12branch.h5'), monitor=check_monitor, save_best_only=True, verbose=1))

choice_model_list=['InceptionV3']# ['VGG16','ResNet50','InceptionV3','Xception','InceptionResNetV2','NASNetLarge','SEResNet154','SEInceptionV3','SEInceptionResNetV2']
FCnum_list=[None,5]# [None,1,2,3,4,5]
FCpool='GlobalAveragePooling2D'
Dence_1, Dropout_1, addBatchNorm_1, kernel_initializer_1, l2_rate_1=1024, 0.5, None, 'he_normal', 1e-4
Dence_2, Dropout_2, addBatchNorm_2, kernel_initializer_2, l2_rate_2=512, 0.5, None, 'he_normal', 1e-4
Dence_3, Dropout_3, addBatchNorm_3, kernel_initializer_3, l2_rate_3=256, 0.5, None, 'he_normal', 1e-4
Dence_4, Dropout_4, addBatchNorm_4, kernel_initializer_4, l2_rate_4=128, 0.5, None, 'he_normal', 1e-4
Dence_5, Dropout_5, addBatchNorm_5, kernel_initializer_5, l2_rate_5=64, 0.5, None, 'he_normal', 1e-4
pred_kernel_initializer='zeros'
pred_l2_rate=1e-4
activation_list=['sigmoid']# ['sigmoid','softmax']
trainable='all'
gpu_count=len(gpu_num.split(','))
skip_bn=True
opt_list=['nadam']# ['sgd', 'rmsprop', 'adagrad', 'adadelta', 'adam', 'adamax', 'nadam']

for choice_model in choice_model_list:
    for FCnum in FCnum_list:
        for activation in activation_list:
            print('\n###################################')
            model, orig_model = define_model.get_12branch_fine_tuning_model(out_dir, shape[0], shape[1], shape[2], num_classes
                                                                    , choice_model, trainable
                                                                    , FCnum
                                                                    , FCpool=FCpool
                                                                    , Dence_1=Dence_1, Dropout_1=Dropout_1, addBatchNorm_1=addBatchNorm_1, kernel_initializer_1=kernel_initializer_1, l2_rate_1=l2_rate_1
                                                                    , Dence_2=Dence_2, Dropout_2=Dropout_2, addBatchNorm_2=addBatchNorm_2, kernel_initializer_2=kernel_initializer_2, l2_rate_2=l2_rate_2
                                                                    , Dence_3=Dence_3, Dropout_3=Dropout_3, addBatchNorm_3=addBatchNorm_3, kernel_initializer_3=kernel_initializer_3, l2_rate_3=l2_rate_3
                                                                    , Dence_4=Dence_4, Dropout_4=Dropout_4, addBatchNorm_4=addBatchNorm_4, kernel_initializer_4=kernel_initializer_4, l2_rate_4=l2_rate_4
                                                                    , Dence_5=Dence_5, Dropout_5=Dropout_5, addBatchNorm_5=addBatchNorm_5, kernel_initializer_5=kernel_initializer_5, l2_rate_5=l2_rate_5
                                                                    , pred_kernel_initializer=pred_kernel_initializer, pred_l2_rate=pred_l2_rate
                                                                    , activation=activation 
                                                                    , gpu_count=gpu_count
                                                                    , skip_bn=skip_bn
                                                                  )
            for opt in opt_list:
                # オプティマイザ
                optim = define_model.get_optimizers(opt, decay=0.0)
                lr_metric = my_metric.get_lr_metric(optim)
                # モデルコンパイル
                model.compile(loss=multi_loss.build_masked_loss(K.binary_crossentropy)
                              , optimizer=optim
                              , metrics=['accuracy', 'binary_accuracy', multi_loss.masked_accuracy, lr_metric])
                
                
                model.fit_generator(generator_multi_train
                    , steps_per_epoch=d_cls.train_steps_per_epoch()
                    , epochs=epochs
                    , validation_data=generator_multi_valid
                    , validation_steps=d_cls.valid_steps_per_epoch()
                    , callbacks=cb
                    , verbose=1)
# Out:
# ###################################
# ----- model_param -----
# output_dir = output_test/100x100
# img_rows img_cols channels = 100 100 3
# num_classes = 12
# choice_model trainable = InceptionV3 all
# FCnum = None
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ---- choice_optim = nadam ----
# nadam_lr nadam_schedule_decay beta_1 beta_2 = 0.002 0.004 0.9 0.999
# Epoch 1/3
# 172/173 [============================>.] - ETA: 0s - loss: 2.1930 - task0_pred_loss: 0.2587 - task1_pred_loss: 0.1457 - task2_pred_loss: 0.1231 - task3_pred_loss: 0.1319 - task4_pred_loss: 0.2513 - task5_pred_loss: 0.1608 - task6_pred_loss: 0.0983 - task7_pred_loss: 0.2700 - task8_pred_loss: 0.1355 - task9_pred_loss: 0.1561 - task10_pred_loss: 0.2779 - task11_pred_loss: 0.1836 - task0_pred_acc: 0.6141 - task0_pred_binary_accuracy: 0.6141 - task0_pred_masked_accuracy: 0.8843 - task0_pred_lr: 0.0015 - task1_pred_acc: 0.7640 - task1_pred_binary_accuracy: 0.7640 - task1_pred_masked_accuracy: 0.9592 - task1_pred_lr: 0.0015 - task2_pred_acc: 0.7052 - task2_pred_binary_accuracy: 0.7052 - task2_pred_masked_accuracy: 0.9646 - task2_pred_lr: 0.0015 - task3_pred_acc: 0.5837 - task3_pred_binary_accuracy: 0.5837 - task3_pred_masked_accuracy: 0.9505 - task3_pred_lr: 0.0015 - task4_pred_acc: 0.5742 - task4_pred_binary_accuracy: 0.5742 - task4_pred_masked_accuracy: 0.8780 - task4_pred_lr: 0.0015 - task5_pred_acc: 0.7064 - task5_pred_binary_accuracy: 0.7064 - task5_pred_masked_accuracy: 0.9492 - task5_pred_lr: 0.0015 - task6_pred_acc: 0.6766 - task6_pred_binary_accuracy: 0.6766 - task6_pred_masked_accuracy: 0.9726 - task6_pred_lr: 0.0015 - task7_pred_acc: 0.5164 - task7_pred_binary_accuracy: 0.5164 - task7_pred_masked_accuracy: 0.8469 - task7_pred_lr: 0.0015 - task8_pred_acc: 0.7442 - task8_pred_binary_accuracy: 0.7442 - task8_pred_masked_accuracy: 0.9627 - task8_pred_lr: 0.0015 - task9_pred_acc: 0.6567 - task9_pred_binary_accuracy: 0.6567 - task9_pred_masked_accuracy: 0.9474 - task9_pred_lr: 0.0015 - task10_pred_acc: 0.5249 - task10_pred_binary_accuracy: 0.5249 - task10_pred_masked_accuracy: 0.8425 - task10_pred_lr: 0.0015 - task11_pred_acc: 0.6884 - task11_pred_binary_accuracy: 0.6884 - task11_pred_masked_accuracy: 0.9380 - task11_pred_lr: 0.0015
# lr: 0.1
# Epoch 00001: val_loss improved from inf to 13.99479, saving model to output_test/100x100/test_model_12branch.h5
# Epoch 00001: val_loss improved from inf to 13.99479, saving model to output_test/100x100/test_model_12branch.h5
# 173/173 [==============================] - 478s 3s/step - loss: 2.1914 - task0_pred_loss: 0.2587 - task1_pred_loss: 0.1456 - task2_pred_loss: 0.1228 - task3_pred_loss: 0.1326 - task4_pred_loss: 0.2513 - task5_pred_loss: 0.1606 - task6_pred_loss: 0.0978 - task7_pred_loss: 0.2698 - task8_pred_loss: 0.1351 - task9_pred_loss: 0.1557 - task10_pred_loss: 0.2775 - task11_pred_loss: 0.1837 - task0_pred_acc: 0.6137 - task0_pred_binary_accuracy: 0.6137 - task0_pred_masked_accuracy: 0.8842 - task0_pred_lr: 0.0015 - task1_pred_acc: 0.7635 - task1_pred_binary_accuracy: 0.7635 - task1_pred_masked_accuracy: 0.9592 - task1_pred_lr: 0.0015 - task2_pred_acc: 0.7052 - task2_pred_binary_accuracy: 0.7052 - task2_pred_masked_accuracy: 0.9647 - task2_pred_lr: 0.0015 - task3_pred_acc: 0.5836 - task3_pred_binary_accuracy: 0.5836 - task3_pred_masked_accuracy: 0.9501 - task3_pred_lr: 0.0015 - task4_pred_acc: 0.5740 - task4_pred_binary_accuracy: 0.5740 - task4_pred_masked_accuracy: 0.8779 - task4_pred_lr: 0.0015 - task5_pred_acc: 0.7061 - task5_pred_binary_accuracy: 0.7061 - task5_pred_masked_accuracy: 0.9492 - task5_pred_lr: 0.0015 - task6_pred_acc: 0.6768 - task6_pred_binary_accuracy: 0.6768 - task6_pred_masked_accuracy: 0.9728 - task6_pred_lr: 0.0015 - task7_pred_acc: 0.5156 - task7_pred_binary_accuracy: 0.5156 - task7_pred_masked_accuracy: 0.8467 - task7_pred_lr: 0.0015 - task8_pred_acc: 0.7440 - task8_pred_binary_accuracy: 0.7440 - task8_pred_masked_accuracy: 0.9628 - task8_pred_lr: 0.0015 - task9_pred_acc: 0.6564 - task9_pred_binary_accuracy: 0.6564 - task9_pred_masked_accuracy: 0.9476 - task9_pred_lr: 0.0015 - task10_pred_acc: 0.5245 - task10_pred_binary_accuracy: 0.5245 - task10_pred_masked_accuracy: 0.8426 - task10_pred_lr: 0.0015 - task11_pred_acc: 0.6883 - task11_pred_binary_accuracy: 0.6883 - task11_pred_masked_accuracy: 0.9379 - task11_pred_lr: 0.0015 - val_loss: 13.9948 - val_task0_pred_loss: 1.6880 - val_task1_pred_loss: 0.1634 - val_task2_pred_loss: 0.2178 - val_task3_pred_loss: 0.9802 - val_task4_pred_loss: 1.4702 - val_task5_pred_loss: 0.5445 - val_task6_pred_loss: 0.8168 - val_task7_pred_loss: 2.6137 - val_task8_pred_loss: 1.3613 - val_task9_pred_loss: 0.5445 - val_task10_pred_loss: 2.0692 - val_task11_pred_loss: 1.5247 - val_task0_pred_acc: 0.8142 - val_task0_pred_binary_accuracy: 0.8142 - val_task0_pred_masked_accuracy: 0.8865 - val_task0_pred_lr: 0.0015 - val_task1_pred_acc: 0.9764 - val_task1_pred_binary_accuracy: 0.9764 - val_task1_pred_masked_accuracy: 0.9898 - val_task1_pred_lr: 0.0015 - val_task2_pred_acc: 0.8412 - val_task2_pred_binary_accuracy: 0.8412 - val_task2_pred_masked_accuracy: 0.9847 - val_task2_pred_lr: 0.0015 - val_task3_pred_acc: 0.6622 - val_task3_pred_binary_accuracy: 0.6622 - val_task3_pred_masked_accuracy: 0.9173 - val_task3_pred_lr: 0.0015 - val_task4_pred_acc: 0.8041 - val_task4_pred_binary_accuracy: 0.8041 - val_task4_pred_masked_accuracy: 0.8991 - val_task4_pred_lr: 0.0015 - val_task5_pred_acc: 0.9358 - val_task5_pred_binary_accuracy: 0.9358 - val_task5_pred_masked_accuracy: 0.9648 - val_task5_pred_lr: 0.0015 - val_task6_pred_acc: 0.8514 - val_task6_pred_binary_accuracy: 0.8514 - val_task6_pred_masked_accuracy: 0.9443 - val_task6_pred_lr: 0.0015 - val_task7_pred_acc: 0.6284 - val_task7_pred_binary_accuracy: 0.6284 - val_task7_pred_masked_accuracy: 0.7952 - val_task7_pred_lr: 0.0015 - val_task8_pred_acc: 0.8345 - val_task8_pred_binary_accuracy: 0.8345 - val_task8_pred_masked_accuracy: 0.9079 - val_task8_pred_lr: 0.0015 - val_task9_pred_acc: 0.8682 - val_task9_pred_binary_accuracy: 0.8682 - val_task9_pred_masked_accuracy: 0.9622 - val_task9_pred_lr: 0.0015 - val_task10_pred_acc: 0.6757 - val_task10_pred_binary_accuracy: 0.6757 - val_task10_pred_masked_accuracy: 0.8421 - val_task10_pred_lr: 0.0015 - val_task11_pred_acc: 0.8142 - val_task11_pred_binary_accuracy: 0.8142 - val_task11_pred_masked_accuracy: 0.8958 - val_task11_pred_lr: 0.0015
# Epoch 2/3
# 172/173 [============================>.] - ETA: 0s - loss: 2.0832 - task0_pred_loss: 0.2504 - task1_pred_loss: 0.1370 - task2_pred_loss: 0.1132 - task3_pred_loss: 0.1232 - task4_pred_loss: 0.2424 - task5_pred_loss: 0.1509 - task6_pred_loss: 0.0886 - task7_pred_loss: 0.2640 - task8_pred_loss: 0.1257 - task9_pred_loss: 0.1446 - task10_pred_loss: 0.2701 - task11_pred_loss: 0.1726 - task0_pred_acc: 0.6131 - task0_pred_binary_accuracy: 0.6131 - task0_pred_masked_accuracy: 0.8839 - task0_pred_lr: 5.1500e-04 - task1_pred_acc: 0.7634 - task1_pred_binary_accuracy: 0.7634 - task1_pred_masked_accuracy: 0.9596 - task1_pred_lr: 5.1500e-04 - task2_pred_acc: 0.7050 - task2_pred_binary_accuracy: 0.7050 - task2_pred_masked_accuracy: 0.9648 - task2_pred_lr: 5.1500e-04 - task3_pred_acc: 0.5838 - task3_pred_binary_accuracy: 0.5838 - task3_pred_masked_accuracy: 0.9503 - task3_pred_lr: 5.1500e-04 - task4_pred_acc: 0.5741 - task4_pred_binary_accuracy: 0.5741 - task4_pred_masked_accuracy: 0.8782 - task4_pred_lr: 5.1500e-04 - task5_pred_acc: 0.7060 - task5_pred_binary_accuracy: 0.7060 - task5_pred_masked_accuracy: 0.9492 - task5_pred_lr: 5.1500e-04 - task6_pred_acc: 0.6764 - task6_pred_binary_accuracy: 0.6764 - task6_pred_masked_accuracy: 0.9728 - task6_pred_lr: 5.1500e-04 - task7_pred_acc: 0.5156 - task7_pred_binary_accuracy: 0.5156 - task7_pred_masked_accuracy: 0.8458 - task7_pred_lr: 5.1500e-04 - task8_pred_acc: 0.7438 - task8_pred_binary_accuracy: 0.7438 - task8_pred_masked_accuracy: 0.9625 - task8_pred_lr: 5.1500e-04 - task9_pred_acc: 0.6566 - task9_pred_binary_accuracy: 0.6566 - task9_pred_masked_accuracy: 0.9475 - task9_pred_lr: 5.1500e-04 - task10_pred_acc: 0.5247 - task10_pred_binary_accuracy: 0.5247 - task10_pred_masked_accuracy: 0.8434 - task10_pred_lr: 5.1500e-04 - task11_pred_acc: 0.6879 - task11_pred_binary_accuracy: 0.6879 - task11_pred_masked_accuracy: 0.9377 - task11_pred_lr: 5.1500e-04
# lr: 0.1
# Epoch 00002: val_loss improved from 13.99479 to 2.87680, saving model to output_test/100x100/test_model_12branch.h5
# Epoch 00002: val_loss improved from 13.99479 to 2.87680, saving model to output_test/100x100/test_model_12branch.h5
# 173/173 [==============================] - 82s 473ms/step - loss: 2.0817 - task0_pred_loss: 0.2502 - task1_pred_loss: 0.1372 - task2_pred_loss: 0.1132 - task3_pred_loss: 0.1229 - task4_pred_loss: 0.2427 - task5_pred_loss: 0.1510 - task6_pred_loss: 0.0882 - task7_pred_loss: 0.2636 - task8_pred_loss: 0.1252 - task9_pred_loss: 0.1447 - task10_pred_loss: 0.2699 - task11_pred_loss: 0.1723 - task0_pred_acc: 0.6137 - task0_pred_binary_accuracy: 0.6137 - task0_pred_masked_accuracy: 0.8842 - task0_pred_lr: 5.1500e-04 - task1_pred_acc: 0.7635 - task1_pred_binary_accuracy: 0.7635 - task1_pred_masked_accuracy: 0.9595 - task1_pred_lr: 5.1500e-04 - task2_pred_acc: 0.7052 - task2_pred_binary_accuracy: 0.7052 - task2_pred_masked_accuracy: 0.9647 - task2_pred_lr: 5.1500e-04 - task3_pred_acc: 0.5836 - task3_pred_binary_accuracy: 0.5836 - task3_pred_masked_accuracy: 0.9504 - task3_pred_lr: 5.1500e-04 - task4_pred_acc: 0.5746 - task4_pred_binary_accuracy: 0.5746 - task4_pred_masked_accuracy: 0.8782 - task4_pred_lr: 5.1500e-04 - task5_pred_acc: 0.7061 - task5_pred_binary_accuracy: 0.7061 - task5_pred_masked_accuracy: 0.9491 - task5_pred_lr: 5.1500e-04 - task6_pred_acc: 0.6768 - task6_pred_binary_accuracy: 0.6768 - task6_pred_masked_accuracy: 0.9729 - task6_pred_lr: 5.1500e-04 - task7_pred_acc: 0.5159 - task7_pred_binary_accuracy: 0.5159 - task7_pred_masked_accuracy: 0.8463 - task7_pred_lr: 5.1500e-04 - task8_pred_acc: 0.7440 - task8_pred_binary_accuracy: 0.7440 - task8_pred_masked_accuracy: 0.9627 - task8_pred_lr: 5.1500e-04 - task9_pred_acc: 0.6564 - task9_pred_binary_accuracy: 0.6564 - task9_pred_masked_accuracy: 0.9474 - task9_pred_lr: 5.1500e-04 - task10_pred_acc: 0.5252 - task10_pred_binary_accuracy: 0.5252 - task10_pred_masked_accuracy: 0.8437 - task10_pred_lr: 5.1500e-04 - task11_pred_acc: 0.6883 - task11_pred_binary_accuracy: 0.6883 - task11_pred_masked_accuracy: 0.9378 - task11_pred_lr: 5.1500e-04 - val_loss: 2.8768 - val_task0_pred_loss: 0.3260 - val_task1_pred_loss: 0.0725 - val_task2_pred_loss: 0.0810 - val_task3_pred_loss: 0.2130 - val_task4_pred_loss: 0.2952 - val_task5_pred_loss: 0.1476 - val_task6_pred_loss: 0.2011 - val_task7_pred_loss: 0.4062 - val_task8_pred_loss: 0.3140 - val_task9_pred_loss: 0.1525 - val_task10_pred_loss: 0.3531 - val_task11_pred_loss: 0.3143 - val_task0_pred_acc: 0.8142 - val_task0_pred_binary_accuracy: 0.8142 - val_task0_pred_masked_accuracy: 0.8865 - val_task0_pred_lr: 5.1500e-04 - val_task1_pred_acc: 0.9764 - val_task1_pred_binary_accuracy: 0.9764 - val_task1_pred_masked_accuracy: 0.9898 - val_task1_pred_lr: 5.1500e-04 - val_task2_pred_acc: 0.8412 - val_task2_pred_binary_accuracy: 0.8412 - val_task2_pred_masked_accuracy: 0.9847 - val_task2_pred_lr: 5.1500e-04 - val_task3_pred_acc: 0.6622 - val_task3_pred_binary_accuracy: 0.6622 - val_task3_pred_masked_accuracy: 0.9173 - val_task3_pred_lr: 5.1500e-04 - val_task4_pred_acc: 0.8041 - val_task4_pred_binary_accuracy: 0.8041 - val_task4_pred_masked_accuracy: 0.8991 - val_task4_pred_lr: 5.1500e-04 - val_task5_pred_acc: 0.9358 - val_task5_pred_binary_accuracy: 0.9358 - val_task5_pred_masked_accuracy: 0.9648 - val_task5_pred_lr: 5.1500e-04 - val_task6_pred_acc: 0.8514 - val_task6_pred_binary_accuracy: 0.8514 - val_task6_pred_masked_accuracy: 0.9443 - val_task6_pred_lr: 5.1500e-04 - val_task7_pred_acc: 0.6284 - val_task7_pred_binary_accuracy: 0.6284 - val_task7_pred_masked_accuracy: 0.7952 - val_task7_pred_lr: 5.1500e-04 - val_task8_pred_acc: 0.8345 - val_task8_pred_binary_accuracy: 0.8345 - val_task8_pred_masked_accuracy: 0.9079 - val_task8_pred_lr: 5.1500e-04 - val_task9_pred_acc: 0.8682 - val_task9_pred_binary_accuracy: 0.8682 - val_task9_pred_masked_accuracy: 0.9622 - val_task9_pred_lr: 5.1500e-04 - val_task10_pred_acc: 0.6757 - val_task10_pred_binary_accuracy: 0.6757 - val_task10_pred_masked_accuracy: 0.8421 - val_task10_pred_lr: 5.1500e-04 - val_task11_pred_acc: 0.8142 - val_task11_pred_binary_accuracy: 0.8142 - val_task11_pred_masked_accuracy: 0.8958 - val_tas ...
# Epoch 3/3
# 172/173 [============================>.] - ETA: 0s - loss: 2.0675 - task0_pred_loss: 0.2485 - task1_pred_loss: 0.1354 - task2_pred_loss: 0.1123 - task3_pred_loss: 0.1211 - task4_pred_loss: 0.2426 - task5_pred_loss: 0.1514 - task6_pred_loss: 0.0874 - task7_pred_loss: 0.2613 - task8_pred_loss: 0.1241 - task9_pred_loss: 0.1442 - task10_pred_loss: 0.2667 - task11_pred_loss: 0.1723 - task0_pred_acc: 0.6135 - task0_pred_binary_accuracy: 0.6135 - task0_pred_masked_accuracy: 0.8834 - task0_pred_lr: 2.0000e-05 - task1_pred_acc: 0.7636 - task1_pred_binary_accuracy: 0.7636 - task1_pred_masked_accuracy: 0.9594 - task1_pred_lr: 2.0000e-05 - task2_pred_acc: 0.7053 - task2_pred_binary_accuracy: 0.7053 - task2_pred_masked_accuracy: 0.9646 - task2_pred_lr: 2.0000e-05 - task3_pred_acc: 0.5836 - task3_pred_binary_accuracy: 0.5836 - task3_pred_masked_accuracy: 0.9498 - task3_pred_lr: 2.0000e-05 - task4_pred_acc: 0.5746 - task4_pred_binary_accuracy: 0.5746 - task4_pred_masked_accuracy: 0.8785 - task4_pred_lr: 2.0000e-05 - task5_pred_acc: 0.7060 - task5_pred_binary_accuracy: 0.7060 - task5_pred_masked_accuracy: 0.9489 - task5_pred_lr: 2.0000e-05 - task6_pred_acc: 0.6768 - task6_pred_binary_accuracy: 0.6768 - task6_pred_masked_accuracy: 0.9728 - task6_pred_lr: 2.0000e-05 - task7_pred_acc: 0.5156 - task7_pred_binary_accuracy: 0.5156 - task7_pred_masked_accuracy: 0.8467 - task7_pred_lr: 2.0000e-05 - task8_pred_acc: 0.7442 - task8_pred_binary_accuracy: 0.7442 - task8_pred_masked_accuracy: 0.9628 - task8_pred_lr: 2.0000e-05 - task9_pred_acc: 0.6562 - task9_pred_binary_accuracy: 0.6562 - task9_pred_masked_accuracy: 0.9471 - task9_pred_lr: 2.0000e-05 - task10_pred_acc: 0.5253 - task10_pred_binary_accuracy: 0.5253 - task10_pred_masked_accuracy: 0.8437 - task10_pred_lr: 2.0000e-05 - task11_pred_acc: 0.6884 - task11_pred_binary_accuracy: 0.6884 - task11_pred_masked_accuracy: 0.9374 - task11_pred_lr: 2.0000e-05
# lr: 0.1
# Epoch 00003: val_loss improved from 2.87680 to 2.87593, saving model to output_test/100x100/test_model_12branch.h5
# Epoch 00003: val_loss improved from 2.87680 to 2.87593, saving model to output_test/100x100/test_model_12branch.h5
# 173/173 [==============================] - 82s 473ms/step - loss: 2.0613 - task0_pred_loss: 0.2476 - task1_pred_loss: 0.1347 - task2_pred_loss: 0.1118 - task3_pred_loss: 0.1205 - task4_pred_loss: 0.2421 - task5_pred_loss: 0.1507 - task6_pred_loss: 0.0873 - task7_pred_loss: 0.2610 - task8_pred_loss: 0.1235 - task9_pred_loss: 0.1435 - task10_pred_loss: 0.2666 - task11_pred_loss: 0.1715 - task0_pred_acc: 0.6137 - task0_pred_binary_accuracy: 0.6137 - task0_pred_masked_accuracy: 0.8840 - task0_pred_lr: 2.0000e-05 - task1_pred_acc: 0.7635 - task1_pred_binary_accuracy: 0.7635 - task1_pred_masked_accuracy: 0.9596 - task1_pred_lr: 2.0000e-05 - task2_pred_acc: 0.7052 - task2_pred_binary_accuracy: 0.7052 - task2_pred_masked_accuracy: 0.9648 - task2_pred_lr: 2.0000e-05 - task3_pred_acc: 0.5836 - task3_pred_binary_accuracy: 0.5836 - task3_pred_masked_accuracy: 0.9500 - task3_pred_lr: 2.0000e-05 - task4_pred_acc: 0.5746 - task4_pred_binary_accuracy: 0.5746 - task4_pred_masked_accuracy: 0.8788 - task4_pred_lr: 2.0000e-05 - task5_pred_acc: 0.7061 - task5_pred_binary_accuracy: 0.7061 - task5_pred_masked_accuracy: 0.9492 - task5_pred_lr: 2.0000e-05 - task6_pred_acc: 0.6768 - task6_pred_binary_accuracy: 0.6768 - task6_pred_masked_accuracy: 0.9728 - task6_pred_lr: 2.0000e-05 - task7_pred_acc: 0.5159 - task7_pred_binary_accuracy: 0.5159 - task7_pred_masked_accuracy: 0.8470 - task7_pred_lr: 2.0000e-05 - task8_pred_acc: 0.7440 - task8_pred_binary_accuracy: 0.7440 - task8_pred_masked_accuracy: 0.9630 - task8_pred_lr: 2.0000e-05 - task9_pred_acc: 0.6564 - task9_pred_binary_accuracy: 0.6564 - task9_pred_masked_accuracy: 0.9474 - task9_pred_lr: 2.0000e-05 - task10_pred_acc: 0.5252 - task10_pred_binary_accuracy: 0.5252 - task10_pred_masked_accuracy: 0.8438 - task10_pred_lr: 2.0000e-05 - task11_pred_acc: 0.6883 - task11_pred_binary_accuracy: 0.6883 - task11_pred_masked_accuracy: 0.9378 - task11_pred_lr: 2.0000e-05 - val_loss: 2.8759 - val_task0_pred_loss: 0.3267 - val_task1_pred_loss: 0.0749 - val_task2_pred_loss: 0.0780 - val_task3_pred_loss: 0.2136 - val_task4_pred_loss: 0.2999 - val_task5_pred_loss: 0.1481 - val_task6_pred_loss: 0.2023 - val_task7_pred_loss: 0.4066 - val_task8_pred_loss: 0.3112 - val_task9_pred_loss: 0.1488 - val_task10_pred_loss: 0.3517 - val_task11_pred_loss: 0.3136 - val_task0_pred_acc: 0.8142 - val_task0_pred_binary_accuracy: 0.8142 - val_task0_pred_masked_accuracy: 0.8865 - val_task0_pred_lr: 2.0000e-05 - val_task1_pred_acc: 0.9764 - val_task1_pred_binary_accuracy: 0.9764 - val_task1_pred_masked_accuracy: 0.9898 - val_task1_pred_lr: 2.0000e-05 - val_task2_pred_acc: 0.8412 - val_task2_pred_binary_accuracy: 0.8412 - val_task2_pred_masked_accuracy: 0.9847 - val_task2_pred_lr: 2.0000e-05 - val_task3_pred_acc: 0.6622 - val_task3_pred_binary_accuracy: 0.6622 - val_task3_pred_masked_accuracy: 0.9173 - val_task3_pred_lr: 2.0000e-05 - val_task4_pred_acc: 0.8041 - val_task4_pred_binary_accuracy: 0.8041 - val_task4_pred_masked_accuracy: 0.8991 - val_task4_pred_lr: 2.0000e-05 - val_task5_pred_acc: 0.9358 - val_task5_pred_binary_accuracy: 0.9358 - val_task5_pred_masked_accuracy: 0.9648 - val_task5_pred_lr: 2.0000e-05 - val_task6_pred_acc: 0.8514 - val_task6_pred_binary_accuracy: 0.8514 - val_task6_pred_masked_accuracy: 0.9443 - val_task6_pred_lr: 2.0000e-05 - val_task7_pred_acc: 0.6284 - val_task7_pred_binary_accuracy: 0.6284 - val_task7_pred_masked_accuracy: 0.7952 - val_task7_pred_lr: 2.0000e-05 - val_task8_pred_acc: 0.8345 - val_task8_pred_binary_accuracy: 0.8345 - val_task8_pred_masked_accuracy: 0.9079 - val_task8_pred_lr: 2.0000e-05 - val_task9_pred_acc: 0.8682 - val_task9_pred_binary_accuracy: 0.8682 - val_task9_pred_masked_accuracy: 0.9622 - val_task9_pred_lr: 2.0000e-05 - val_task10_pred_acc: 0.6757 - val_task10_pred_binary_accuracy: 0.6757 - val_task10_pred_masked_accuracy: 0.8421 - val_task10_pred_lr: 2.0000e-05 - val_task11_pred_acc: 0.8142 - val_task11_pred_binary_accuracy: 0.8142 - val_task11_pred_masked_accuracy: 0.8958 - val_tas ...
#
# ###################################
# ----- model_param -----
# output_dir = output_test/100x100
# img_rows img_cols channels = 100 100 3
# num_classes = 12
# choice_model trainable = InceptionV3 all
# FCnum = 5
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ----- FC_layer -----
# dence dropout addBatchNorm kernel_initializer l2_rate = 1024 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 512 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 256 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 128 0.5 None he_normal 0.0001
# dence dropout addBatchNorm kernel_initializer l2_rate = 64 0.5 None he_normal 0.0001
# ---- choice_optim = nadam ----
# nadam_lr nadam_schedule_decay beta_1 beta_2 = 0.002 0.004 0.9 0.999
# Epoch 1/3
# 172/173 [============================>.] - ETA: 0s - loss: 3.8508 - task0_pred_loss: 0.2804 - task1_pred_loss: 0.1726 - task2_pred_loss: 0.1412 - task3_pred_loss: 0.1528 - task4_pred_loss: 0.2775 - task5_pred_loss: 0.1803 - task6_pred_loss: 0.1153 - task7_pred_loss: 0.3017 - task8_pred_loss: 0.1558 - task9_pred_loss: 0.1781 - task10_pred_loss: 0.3049 - task11_pred_loss: 0.2085 - task0_pred_acc: 0.6135 - task0_pred_binary_accuracy: 0.6135 - task0_pred_masked_accuracy: 0.8857 - task0_pred_lr: 0.0015 - task1_pred_acc: 0.7629 - task1_pred_binary_accuracy: 0.7629 - task1_pred_masked_accuracy: 0.9589 - task1_pred_lr: 0.0015 - task2_pred_acc: 0.7061 - task2_pred_binary_accuracy: 0.7061 - task2_pred_masked_accuracy: 0.9642 - task2_pred_lr: 0.0015 - task3_pred_acc: 0.5843 - task3_pred_binary_accuracy: 0.5843 - task3_pred_masked_accuracy: 0.9504 - task3_pred_lr: 0.0015 - task4_pred_acc: 0.5754 - task4_pred_binary_accuracy: 0.5754 - task4_pred_masked_accuracy: 0.8783 - task4_pred_lr: 0.0015 - task5_pred_acc: 0.7073 - task5_pred_binary_accuracy: 0.7073 - task5_pred_masked_accuracy: 0.9507 - task5_pred_lr: 0.0015 - task6_pred_acc: 0.6784 - task6_pred_binary_accuracy: 0.6784 - task6_pred_masked_accuracy: 0.9735 - task6_pred_lr: 0.0015 - task7_pred_acc: 0.5155 - task7_pred_binary_accuracy: 0.5155 - task7_pred_masked_accuracy: 0.8459 - task7_pred_lr: 0.0015 - task8_pred_acc: 0.7441 - task8_pred_binary_accuracy: 0.7441 - task8_pred_masked_accuracy: 0.9631 - task8_pred_lr: 0.0015 - task9_pred_acc: 0.6557 - task9_pred_binary_accuracy: 0.6557 - task9_pred_masked_accuracy: 0.9473 - task9_pred_lr: 0.0015 - task10_pred_acc: 0.5249 - task10_pred_binary_accuracy: 0.5249 - task10_pred_masked_accuracy: 0.8455 - task10_pred_lr: 0.0015 - task11_pred_acc: 0.6878 - task11_pred_binary_accuracy: 0.6878 - task11_pred_masked_accuracy: 0.9372 - task11_pred_lr: 0.0015
# lr: 0.1
# Epoch 00001: val_loss did not improve
# Epoch 00001: val_loss did not improve
# 173/173 [==============================] - 117s 676ms/step - loss: 3.8475 - task0_pred_loss: 0.2804 - task1_pred_loss: 0.1734 - task2_pred_loss: 0.1410 - task3_pred_loss: 0.1520 - task4_pred_loss: 0.2776 - task5_pred_loss: 0.1805 - task6_pred_loss: 0.1153 - task7_pred_loss: 0.3014 - task8_pred_loss: 0.1568 - task9_pred_loss: 0.1778 - task10_pred_loss: 0.3051 - task11_pred_loss: 0.2085 - task0_pred_acc: 0.6128 - task0_pred_binary_accuracy: 0.6128 - task0_pred_masked_accuracy: 0.8854 - task0_pred_lr: 0.0015 - task1_pred_acc: 0.7617 - task1_pred_binary_accuracy: 0.7617 - task1_pred_masked_accuracy: 0.9584 - task1_pred_lr: 0.0015 - task2_pred_acc: 0.7050 - task2_pred_binary_accuracy: 0.7050 - task2_pred_masked_accuracy: 0.9641 - task2_pred_lr: 0.0015 - task3_pred_acc: 0.5838 - task3_pred_binary_accuracy: 0.5838 - task3_pred_masked_accuracy: 0.9507 - task3_pred_lr: 0.0015 - task4_pred_acc: 0.5748 - task4_pred_binary_accuracy: 0.5748 - task4_pred_masked_accuracy: 0.8778 - task4_pred_lr: 0.0015 - task5_pred_acc: 0.7063 - task5_pred_binary_accuracy: 0.7063 - task5_pred_masked_accuracy: 0.9504 - task5_pred_lr: 0.0015 - task6_pred_acc: 0.6774 - task6_pred_binary_accuracy: 0.6774 - task6_pred_masked_accuracy: 0.9733 - task6_pred_lr: 0.0015 - task7_pred_acc: 0.5152 - task7_pred_binary_accuracy: 0.5152 - task7_pred_masked_accuracy: 0.8459 - task7_pred_lr: 0.0015 - task8_pred_acc: 0.7429 - task8_pred_binary_accuracy: 0.7429 - task8_pred_masked_accuracy: 0.9626 - task8_pred_lr: 0.0015 - task9_pred_acc: 0.6556 - task9_pred_binary_accuracy: 0.6556 - task9_pred_masked_accuracy: 0.9474 - task9_pred_lr: 0.0015 - task10_pred_acc: 0.5239 - task10_pred_binary_accuracy: 0.5239 - task10_pred_masked_accuracy: 0.8447 - task10_pred_lr: 0.0015 - task11_pred_acc: 0.6870 - task11_pred_binary_accuracy: 0.6870 - task11_pred_masked_accuracy: 0.9370 - task11_pred_lr: 0.0015 - val_loss: 3.6608 - val_task0_pred_loss: 0.3283 - val_task1_pred_loss: 0.1402 - val_task2_pred_loss: 0.0866 - val_task3_pred_loss: 0.2575 - val_task4_pred_loss: 0.3034 - val_task5_pred_loss: 0.1587 - val_task6_pred_loss: 0.2028 - val_task7_pred_loss: 0.4041 - val_task8_pred_loss: 0.2824 - val_task9_pred_loss: 0.1462 - val_task10_pred_loss: 0.3681 - val_task11_pred_loss: 0.3018 - val_task0_pred_acc: 0.8142 - val_task0_pred_binary_accuracy: 0.8142 - val_task0_pred_masked_accuracy: 0.8865 - val_task0_pred_lr: 0.0015 - val_task1_pred_acc: 0.9764 - val_task1_pred_binary_accuracy: 0.9764 - val_task1_pred_masked_accuracy: 0.9898 - val_task1_pred_lr: 0.0015 - val_task2_pred_acc: 0.8412 - val_task2_pred_binary_accuracy: 0.8412 - val_task2_pred_masked_accuracy: 0.9847 - val_task2_pred_lr: 0.0015 - val_task3_pred_acc: 0.6622 - val_task3_pred_binary_accuracy: 0.6622 - val_task3_pred_masked_accuracy: 0.9173 - val_task3_pred_lr: 0.0015 - val_task4_pred_acc: 0.8041 - val_task4_pred_binary_accuracy: 0.8041 - val_task4_pred_masked_accuracy: 0.8991 - val_task4_pred_lr: 0.0015 - val_task5_pred_acc: 0.9358 - val_task5_pred_binary_accuracy: 0.9358 - val_task5_pred_masked_accuracy: 0.9648 - val_task5_pred_lr: 0.0015 - val_task6_pred_acc: 0.8514 - val_task6_pred_binary_accuracy: 0.8514 - val_task6_pred_masked_accuracy: 0.9443 - val_task6_pred_lr: 0.0015 - val_task7_pred_acc: 0.6284 - val_task7_pred_binary_accuracy: 0.6284 - val_task7_pred_masked_accuracy: 0.7952 - val_task7_pred_lr: 0.0015 - val_task8_pred_acc: 0.8345 - val_task8_pred_binary_accuracy: 0.8345 - val_task8_pred_masked_accuracy: 0.9079 - val_task8_pred_lr: 0.0015 - val_task9_pred_acc: 0.8682 - val_task9_pred_binary_accuracy: 0.8682 - val_task9_pred_masked_accuracy: 0.9622 - val_task9_pred_lr: 0.0015 - val_task10_pred_acc: 0.6757 - val_task10_pred_binary_accuracy: 0.6757 - val_task10_pred_masked_accuracy: 0.8421 - val_task10_pred_lr: 0.0015 - val_task11_pred_acc: 0.8142 - val_task11_pred_binary_accuracy: 0.8142 - val_task11_pred_masked_accuracy: 0.8958 - val_task11_pred_lr: 0.0015
# Epoch 2/3
# 172/173 [============================>.] - ETA: 0s - loss: 2.8685 - task0_pred_loss: 0.2777 - task1_pred_loss: 0.1500 - task2_pred_loss: 0.1178 - task3_pred_loss: 0.1344 - task4_pred_loss: 0.2612 - task5_pred_loss: 0.1655 - task6_pred_loss: 0.0966 - task7_pred_loss: 0.2778 - task8_pred_loss: 0.1356 - task9_pred_loss: 0.1614 - task10_pred_loss: 0.2970 - task11_pred_loss: 0.1923 - task0_pred_acc: 0.6127 - task0_pred_binary_accuracy: 0.6127 - task0_pred_masked_accuracy: 0.8821 - task0_pred_lr: 5.1500e-04 - task1_pred_acc: 0.7652 - task1_pred_binary_accuracy: 0.7652 - task1_pred_masked_accuracy: 0.9604 - task1_pred_lr: 5.1500e-04 - task2_pred_acc: 0.7061 - task2_pred_binary_accuracy: 0.7061 - task2_pred_masked_accuracy: 0.9656 - task2_pred_lr: 5.1500e-04 - task3_pred_acc: 0.5833 - task3_pred_binary_accuracy: 0.5833 - task3_pred_masked_accuracy: 0.9485 - task3_pred_lr: 5.1500e-04 - task4_pred_acc: 0.5733 - task4_pred_binary_accuracy: 0.5733 - task4_pred_masked_accuracy: 0.8775 - task4_pred_lr: 5.1500e-04 - task5_pred_acc: 0.7060 - task5_pred_binary_accuracy: 0.7060 - task5_pred_masked_accuracy: 0.9487 - task5_pred_lr: 5.1500e-04 - task6_pred_acc: 0.6768 - task6_pred_binary_accuracy: 0.6768 - task6_pred_masked_accuracy: 0.9727 - task6_pred_lr: 5.1500e-04 - task7_pred_acc: 0.5165 - task7_pred_binary_accuracy: 0.5165 - task7_pred_masked_accuracy: 0.8482 - task7_pred_lr: 5.1500e-04 - task8_pred_acc: 0.7456 - task8_pred_binary_accuracy: 0.7456 - task8_pred_masked_accuracy: 0.9638 - task8_pred_lr: 5.1500e-04 - task9_pred_acc: 0.6559 - task9_pred_binary_accuracy: 0.6559 - task9_pred_masked_accuracy: 0.9473 - task9_pred_lr: 5.1500e-04 - task10_pred_acc: 0.5268 - task10_pred_binary_accuracy: 0.5268 - task10_pred_masked_accuracy: 0.8438 - task10_pred_lr: 5.1500e-04 - task11_pred_acc: 0.6896 - task11_pred_binary_accuracy: 0.6896 - task11_pred_masked_accuracy: 0.9390 - task11_pred_lr: 5.1500e-04
# lr: 0.1
# Epoch 00002: val_loss did not improve
# Epoch 00002: val_loss did not improve
# 173/173 [==============================] - 103s 597ms/step - loss: 2.8689 - task0_pred_loss: 0.2772 - task1_pred_loss: 0.1504 - task2_pred_loss: 0.1184 - task3_pred_loss: 0.1339 - task4_pred_loss: 0.2619 - task5_pred_loss: 0.1660 - task6_pred_loss: 0.0967 - task7_pred_loss: 0.2787 - task8_pred_loss: 0.1353 - task9_pred_loss: 0.1610 - task10_pred_loss: 0.2966 - task11_pred_loss: 0.1919 - task0_pred_acc: 0.6131 - task0_pred_binary_accuracy: 0.6131 - task0_pred_masked_accuracy: 0.8825 - task0_pred_lr: 5.1500e-04 - task1_pred_acc: 0.7649 - task1_pred_binary_accuracy: 0.7649 - task1_pred_masked_accuracy: 0.9602 - task1_pred_lr: 5.1500e-04 - task2_pred_acc: 0.7055 - task2_pred_binary_accuracy: 0.7055 - task2_pred_masked_accuracy: 0.9653 - task2_pred_lr: 5.1500e-04 - task3_pred_acc: 0.5830 - task3_pred_binary_accuracy: 0.5830 - task3_pred_masked_accuracy: 0.9487 - task3_pred_lr: 5.1500e-04 - task4_pred_acc: 0.5727 - task4_pred_binary_accuracy: 0.5727 - task4_pred_masked_accuracy: 0.8769 - task4_pred_lr: 5.1500e-04 - task5_pred_acc: 0.7055 - task5_pred_binary_accuracy: 0.7055 - task5_pred_masked_accuracy: 0.9484 - task5_pred_lr: 5.1500e-04 - task6_pred_acc: 0.6767 - task6_pred_binary_accuracy: 0.6767 - task6_pred_masked_accuracy: 0.9726 - task6_pred_lr: 5.1500e-04 - task7_pred_acc: 0.5167 - task7_pred_binary_accuracy: 0.5167 - task7_pred_masked_accuracy: 0.8479 - task7_pred_lr: 5.1500e-04 - task8_pred_acc: 0.7456 - task8_pred_binary_accuracy: 0.7456 - task8_pred_masked_accuracy: 0.9639 - task8_pred_lr: 5.1500e-04 - task9_pred_acc: 0.6561 - task9_pred_binary_accuracy: 0.6561 - task9_pred_masked_accuracy: 0.9475 - task9_pred_lr: 5.1500e-04 - task10_pred_acc: 0.5267 - task10_pred_binary_accuracy: 0.5267 - task10_pred_masked_accuracy: 0.8438 - task10_pred_lr: 5.1500e-04 - task11_pred_acc: 0.6895 - task11_pred_binary_accuracy: 0.6895 - task11_pred_masked_accuracy: 0.9391 - task11_pred_lr: 5.1500e-04 - val_loss: 3.4098 - val_task0_pred_loss: 0.3236 - val_task1_pred_loss: 0.0760 - val_task2_pred_loss: 0.0771 - val_task3_pred_loss: 0.2066 - val_task4_pred_loss: 0.3081 - val_task5_pred_loss: 0.1619 - val_task6_pred_loss: 0.2023 - val_task7_pred_loss: 0.3985 - val_task8_pred_loss: 0.3254 - val_task9_pred_loss: 0.1485 - val_task10_pred_loss: 0.3482 - val_task11_pred_loss: 0.3065 - val_task0_pred_acc: 0.8142 - val_task0_pred_binary_accuracy: 0.8142 - val_task0_pred_masked_accuracy: 0.8865 - val_task0_pred_lr: 5.1500e-04 - val_task1_pred_acc: 0.9764 - val_task1_pred_binary_accuracy: 0.9764 - val_task1_pred_masked_accuracy: 0.9898 - val_task1_pred_lr: 5.1500e-04 - val_task2_pred_acc: 0.8412 - val_task2_pred_binary_accuracy: 0.8412 - val_task2_pred_masked_accuracy: 0.9847 - val_task2_pred_lr: 5.1500e-04 - val_task3_pred_acc: 0.6622 - val_task3_pred_binary_accuracy: 0.6622 - val_task3_pred_masked_accuracy: 0.9173 - val_task3_pred_lr: 5.1500e-04 - val_task4_pred_acc: 0.8041 - val_task4_pred_binary_accuracy: 0.8041 - val_task4_pred_masked_accuracy: 0.8991 - val_task4_pred_lr: 5.1500e-04 - val_task5_pred_acc: 0.9358 - val_task5_pred_binary_accuracy: 0.9358 - val_task5_pred_masked_accuracy: 0.9648 - val_task5_pred_lr: 5.1500e-04 - val_task6_pred_acc: 0.8514 - val_task6_pred_binary_accuracy: 0.8514 - val_task6_pred_masked_accuracy: 0.9443 - val_task6_pred_lr: 5.1500e-04 - val_task7_pred_acc: 0.6284 - val_task7_pred_binary_accuracy: 0.6284 - val_task7_pred_masked_accuracy: 0.7952 - val_task7_pred_lr: 5.1500e-04 - val_task8_pred_acc: 0.8345 - val_task8_pred_binary_accuracy: 0.8345 - val_task8_pred_masked_accuracy: 0.9079 - val_task8_pred_lr: 5.1500e-04 - val_task9_pred_acc: 0.8682 - val_task9_pred_binary_accuracy: 0.8682 - val_task9_pred_masked_accuracy: 0.9622 - val_task9_pred_lr: 5.1500e-04 - val_task10_pred_acc: 0.6757 - val_task10_pred_binary_accuracy: 0.6757 - val_task10_pred_masked_accuracy: 0.8421 - val_task10_pred_lr: 5.1500e-04 - val_task11_pred_acc: 0.8142 - val_task11_pred_binary_accuracy: 0.8142 - val_task11_pred_masked_accuracy: 0.8958 - val_ta ...
# Epoch 3/3
# 172/173 [============================>.] - ETA: 0s - loss: 2.7375 - task0_pred_loss: 0.2691 - task1_pred_loss: 0.1352 - task2_pred_loss: 0.1155 - task3_pred_loss: 0.1329 - task4_pred_loss: 0.2621 - task5_pred_loss: 0.1621 - task6_pred_loss: 0.0908 - task7_pred_loss: 0.2794 - task8_pred_loss: 0.1345 - task9_pred_loss: 0.1548 - task10_pred_loss: 0.2888 - task11_pred_loss: 0.1881 - task0_pred_acc: 0.6137 - task0_pred_binary_accuracy: 0.6137 - task0_pred_masked_accuracy: 0.8831 - task0_pred_lr: 2.0000e-05 - task1_pred_acc: 0.7643 - task1_pred_binary_accuracy: 0.7643 - task1_pred_masked_accuracy: 0.9581 - task1_pred_lr: 2.0000e-05 - task2_pred_acc: 0.7072 - task2_pred_binary_accuracy: 0.7072 - task2_pred_masked_accuracy: 0.9642 - task2_pred_lr: 2.0000e-05 - task3_pred_acc: 0.5852 - task3_pred_binary_accuracy: 0.5852 - task3_pred_masked_accuracy: 0.9492 - task3_pred_lr: 2.0000e-05 - task4_pred_acc: 0.5766 - task4_pred_binary_accuracy: 0.5766 - task4_pred_masked_accuracy: 0.8772 - task4_pred_lr: 2.0000e-05 - task5_pred_acc: 0.7076 - task5_pred_binary_accuracy: 0.7076 - task5_pred_masked_accuracy: 0.9485 - task5_pred_lr: 2.0000e-05 - task6_pred_acc: 0.6792 - task6_pred_binary_accuracy: 0.6792 - task6_pred_masked_accuracy: 0.9728 - task6_pred_lr: 2.0000e-05 - task7_pred_acc: 0.5159 - task7_pred_binary_accuracy: 0.5159 - task7_pred_masked_accuracy: 0.8460 - task7_pred_lr: 2.0000e-05 - task8_pred_acc: 0.7452 - task8_pred_binary_accuracy: 0.7452 - task8_pred_masked_accuracy: 0.9625 - task8_pred_lr: 2.0000e-05 - task9_pred_acc: 0.6571 - task9_pred_binary_accuracy: 0.6571 - task9_pred_masked_accuracy: 0.9481 - task9_pred_lr: 2.0000e-05 - task10_pred_acc: 0.5245 - task10_pred_binary_accuracy: 0.5245 - task10_pred_masked_accuracy: 0.8429 - task10_pred_lr: 2.0000e-05 - task11_pred_acc: 0.6893 - task11_pred_binary_accuracy: 0.6893 - task11_pred_masked_accuracy: 0.9376 - task11_pred_lr: 2.0000e-05
# lr: 0.1
# Epoch 00003: val_loss did not improve
# Epoch 00003: val_loss did not improve
# 173/173 [==============================] - 104s 599ms/step - loss: 2.7387 - task0_pred_loss: 0.2700 - task1_pred_loss: 0.1351 - task2_pred_loss: 0.1153 - task3_pred_loss: 0.1331 - task4_pred_loss: 0.2616 - task5_pred_loss: 0.1616 - task6_pred_loss: 0.0912 - task7_pred_loss: 0.2796 - task8_pred_loss: 0.1353 - task9_pred_loss: 0.1549 - task10_pred_loss: 0.2888 - task11_pred_loss: 0.1879 - task0_pred_acc: 0.6129 - task0_pred_binary_accuracy: 0.6129 - task0_pred_masked_accuracy: 0.8824 - task0_pred_lr: 2.0000e-05 - task1_pred_acc: 0.7637 - task1_pred_binary_accuracy: 0.7637 - task1_pred_masked_accuracy: 0.9581 - task1_pred_lr: 2.0000e-05 - task2_pred_acc: 0.7067 - task2_pred_binary_accuracy: 0.7067 - task2_pred_masked_accuracy: 0.9643 - task2_pred_lr: 2.0000e-05 - task3_pred_acc: 0.5849 - task3_pred_binary_accuracy: 0.5849 - task3_pred_masked_accuracy: 0.9489 - task3_pred_lr: 2.0000e-05 - task4_pred_acc: 0.5764 - task4_pred_binary_accuracy: 0.5764 - task4_pred_masked_accuracy: 0.8775 - task4_pred_lr: 2.0000e-05 - task5_pred_acc: 0.7072 - task5_pred_binary_accuracy: 0.7072 - task5_pred_masked_accuracy: 0.9487 - task5_pred_lr: 2.0000e-05 - task6_pred_acc: 0.6785 - task6_pred_binary_accuracy: 0.6785 - task6_pred_masked_accuracy: 0.9727 - task6_pred_lr: 2.0000e-05 - task7_pred_acc: 0.5156 - task7_pred_binary_accuracy: 0.5156 - task7_pred_masked_accuracy: 0.8456 - task7_pred_lr: 2.0000e-05 - task8_pred_acc: 0.7444 - task8_pred_binary_accuracy: 0.7444 - task8_pred_masked_accuracy: 0.9622 - task8_pred_lr: 2.0000e-05 - task9_pred_acc: 0.6567 - task9_pred_binary_accuracy: 0.6567 - task9_pred_masked_accuracy: 0.9480 - task9_pred_lr: 2.0000e-05 - task10_pred_acc: 0.5241 - task10_pred_binary_accuracy: 0.5241 - task10_pred_masked_accuracy: 0.8427 - task10_pred_lr: 2.0000e-05 - task11_pred_acc: 0.6887 - task11_pred_binary_accuracy: 0.6887 - task11_pred_masked_accuracy: 0.9375 - task11_pred_lr: 2.0000e-05 - val_loss: 3.3290 - val_task0_pred_loss: 0.3215 - val_task1_pred_loss: 0.0918 - val_task2_pred_loss: 0.0803 - val_task3_pred_loss: 0.2030 - val_task4_pred_loss: 0.3093 - val_task5_pred_loss: 0.1613 - val_task6_pred_loss: 0.1870 - val_task7_pred_loss: 0.3845 - val_task8_pred_loss: 0.2909 - val_task9_pred_loss: 0.1488 - val_task10_pred_loss: 0.3387 - val_task11_pred_loss: 0.2905 - val_task0_pred_acc: 0.8142 - val_task0_pred_binary_accuracy: 0.8142 - val_task0_pred_masked_accuracy: 0.8865 - val_task0_pred_lr: 2.0000e-05 - val_task1_pred_acc: 0.9764 - val_task1_pred_binary_accuracy: 0.9764 - val_task1_pred_masked_accuracy: 0.9898 - val_task1_pred_lr: 2.0000e-05 - val_task2_pred_acc: 0.8412 - val_task2_pred_binary_accuracy: 0.8412 - val_task2_pred_masked_accuracy: 0.9847 - val_task2_pred_lr: 2.0000e-05 - val_task3_pred_acc: 0.6622 - val_task3_pred_binary_accuracy: 0.6622 - val_task3_pred_masked_accuracy: 0.9173 - val_task3_pred_lr: 2.0000e-05 - val_task4_pred_acc: 0.8041 - val_task4_pred_binary_accuracy: 0.8041 - val_task4_pred_masked_accuracy: 0.8991 - val_task4_pred_lr: 2.0000e-05 - val_task5_pred_acc: 0.9358 - val_task5_pred_binary_accuracy: 0.9358 - val_task5_pred_masked_accuracy: 0.9648 - val_task5_pred_lr: 2.0000e-05 - val_task6_pred_acc: 0.8514 - val_task6_pred_binary_accuracy: 0.8514 - val_task6_pred_masked_accuracy: 0.9443 - val_task6_pred_lr: 2.0000e-05 - val_task7_pred_acc: 0.6284 - val_task7_pred_binary_accuracy: 0.6284 - val_task7_pred_masked_accuracy: 0.7952 - val_task7_pred_lr: 2.0000e-05 - val_task8_pred_acc: 0.8345 - val_task8_pred_binary_accuracy: 0.8345 - val_task8_pred_masked_accuracy: 0.9079 - val_task8_pred_lr: 2.0000e-05 - val_task9_pred_acc: 0.8682 - val_task9_pred_binary_accuracy: 0.8682 - val_task9_pred_masked_accuracy: 0.9622 - val_task9_pred_lr: 2.0000e-05 - val_task10_pred_acc: 0.6757 - val_task10_pred_binary_accuracy: 0.6757 - val_task10_pred_masked_accuracy: 0.8421 - val_task10_pred_lr: 2.0000e-05 - val_task11_pred_acc: 0.8142 - val_task11_pred_binary_accuracy: 0.8142 - val_task11_pred_masked_accuracy: 0.8958 - val_ta ...
# CPU times: user 22min 20s, sys: 1min 20s, total: 23min 40s
# Wall time: 18min 46s

# %%
# %matplotlib inline
plot_12task_log.plot_results(out_dir, os.path.join(out_dir, 'history.tsv'))

# %% [markdown]
# ## model.fit_generator(12branch)
# ## shape=[331, 331, 3]_ResNet50

# %%
# callback
check_monitor='val_loss' # val_loss最少になるモデルを保存する
early_monitor='val_loss' # val_lossが100エポック更新されなければ学習停止する
early_stopping_pati=100
plateau_monitor='val_loss' # val_lossが100エポック更新されなければ学習率0.9倍
plateau_pati=100
plateau_factor=0.9 # plateau_factor=1.0 はエラーになる

cb = []
if gpu_count > 1:
    # マルチGPUでModelCheckpoint使うためのコールバック
    weight_dir = os.path.join(out_dir, 'model_weight')
    os.makedirs(weight_dir, exist_ok=True)
    cb.append(my_callback.MyCheckPoint(orig_model, weight_dir))
    
    # batch_sizeは並列で処理を行うために元々のbatch_sizeをGPUの数だけ掛ける
    train_batch_size = train_batch_size * gpu_count
    valid_batch_size = valid_batch_size * gpu_count
else:
    cb.append(keras.callbacks.TerminateOnNaN())
    #cb.append(keras.callbacks.ModelCheckpoint(filepath=os.path.join(out_dir, 'test_model.h5'), monitor=check_monitor, save_best_only=True, verbose=1))#, monitor='val_acc'
    cb.append(keras.callbacks.EarlyStopping(monitor=early_monitor, patience=early_stopping_pati, verbose=1))
    # ReduceLROnPlateau つけないと学習率csvファイルに記録されない
    plateau = keras.callbacks.ReduceLROnPlateau(
                monitor=plateau_monitor, # モデルの検証データセットでの損失値を監視
                factor=plateau_factor, # コールバックが起動したら学習率をplateau_factor掛ける
                patience=plateau_pati # 検証データでの損失値がplateauエポックにわたって改善しなかった場合はコールバックを起動
                )
    cb.append(plateau)
    
    base_lr = 0.1 * train_batch_size / 128  # adamとかなら1e-3くらい。SGDなら例えば 0.1 * batch_size / 128 とかくらい。nadamなら0.002*10 ?
    lr_decay_rate = 1 / 3
    lr_steps = 4
    cb.append(keras.callbacks.LearningRateScheduler(lambda ep: float(base_lr * lr_decay_rate ** (ep * lr_steps // epochs))))
    
    # 学習率をエポック増やすごとにコサインカーブのように上げ下げする
    ## 引数なしならlr*0.01されるだけ
    cb.append(my_callback.cosine_annealing())
    
    # callbackで学習率表示
    loss_history = my_callback.LossHistory()
    cb.append(loss_history)
    
cb.append(keras.callbacks.CSVLogger(os.path.join(out_dir, 'history.tsv'), separator='\t'))
print(cb)
# Out:
# [<keras.callbacks.TerminateOnNaN object at 0x7f32aed10358>, <keras.callbacks.EarlyStopping object at 0x7f32aed10438>, <keras.callbacks.ReduceLROnPlateau object at 0x7f3115b2ab70>, <keras.callbacks.LearningRateScheduler object at 0x7f3115ac0278>, <model.my_callback.cosine_annealing.<locals>._CosineAnnealing object at 0x7f308d1ab2e8>, <model.my_callback.LossHistory object at 0x7f308d1c28d0>, <keras.callbacks.CSVLogger object at 0x7f308d1f0c88>]

# %%
# %%time
out_dir='output_test/331x331'
train_batch_size=17
valid_batch_size=6
shape=[331, 331, 3]
d_cls = get_train_valid_test.LabeledDataset(shape, train_batch_size, valid_batch_size)
d_cls.load_train_as_image(train_files, y_train)
d_cls.load_validation_as_image(validation_files, y_valid)
d_cls.load_test_as_image(test_files, y_test)
# ImageDataGenerator のオプションを辞書型で詰める
# get_random_eraserでd_clsの値使うのでここで宣言しないとエラーになる
IDG_options={'horizontal_flip': horizontal_flip
             , 'vertical_flip': vertical_flip
             , 'rotation_range': rotation_range
             , 'zoom_range': zoom_range
             , 'shear_range': shear_range
             , 'preprocessing_function': get_random_eraser(v_l=np.min(d_cls.X_train), v_h=np.max(d_cls.X_train))
            }
d_cls.create_generator(IDG_options=IDG_options)
# 12の出力（task）をだすgeneratorにする
generator_multi_train = get_train_valid_test.generator_12output(d_cls.train_gen)
generator_multi_valid = get_train_valid_test.generator_12output(d_cls.valid_gen)


cb.append(keras.callbacks.ModelCheckpoint(filepath=os.path.join(out_dir, 'test_model_12branch.h5'), monitor=check_monitor, save_best_only=True, verbose=1))

choice_model_list=['ResNet50']# ['VGG16','ResNet50','InceptionV3','Xception','InceptionResNetV2','NASNetLarge','SEResNet154','SEInceptionV3','SEInceptionResNetV2']
FCnum_list=[None]# [None,1,2,3,4,5]
FCpool='GlobalAveragePooling2D'
Dence_1, Dropout_1, addBatchNorm_1, kernel_initializer_1, l2_rate_1=1024, 0.5, None, 'he_normal', 1e-4
Dence_2, Dropout_2, addBatchNorm_2, kernel_initializer_2, l2_rate_2=512, 0.5, None, 'he_normal', 1e-4
Dence_3, Dropout_3, addBatchNorm_3, kernel_initializer_3, l2_rate_3=256, 0.5, None, 'he_normal', 1e-4
Dence_4, Dropout_4, addBatchNorm_4, kernel_initializer_4, l2_rate_4=128, 0.5, None, 'he_normal', 1e-4
Dence_5, Dropout_5, addBatchNorm_5, kernel_initializer_5, l2_rate_5=64, 0.5, None, 'he_normal', 1e-4
pred_kernel_initializer='zeros'
pred_l2_rate=1e-4
activation_list=['sigmoid']# ['sigmoid','softmax']
trainable='all'
gpu_count=len(gpu_num.split(','))
skip_bn=True
opt_list=['nadam']# ['sgd', 'rmsprop', 'adagrad', 'adadelta', 'adam', 'adamax', 'nadam']

for choice_model in choice_model_list:
    for FCnum in FCnum_list:
        for activation in activation_list:
            print('\n###################################')
            model, orig_model = define_model.get_12branch_fine_tuning_model(out_dir, shape[0], shape[1], shape[2], num_classes
                                                                    , choice_model, trainable
                                                                    , FCnum
                                                                    , FCpool=FCpool
                                                                    , Dence_1=Dence_1, Dropout_1=Dropout_1, addBatchNorm_1=addBatchNorm_1, kernel_initializer_1=kernel_initializer_1, l2_rate_1=l2_rate_1
                                                                    , Dence_2=Dence_2, Dropout_2=Dropout_2, addBatchNorm_2=addBatchNorm_2, kernel_initializer_2=kernel_initializer_2, l2_rate_2=l2_rate_2
                                                                    , Dence_3=Dence_3, Dropout_3=Dropout_3, addBatchNorm_3=addBatchNorm_3, kernel_initializer_3=kernel_initializer_3, l2_rate_3=l2_rate_3
                                                                    , Dence_4=Dence_4, Dropout_4=Dropout_4, addBatchNorm_4=addBatchNorm_4, kernel_initializer_4=kernel_initializer_4, l2_rate_4=l2_rate_4
                                                                    , Dence_5=Dence_5, Dropout_5=Dropout_5, addBatchNorm_5=addBatchNorm_5, kernel_initializer_5=kernel_initializer_5, l2_rate_5=l2_rate_5
                                                                    , pred_kernel_initializer=pred_kernel_initializer, pred_l2_rate=pred_l2_rate
                                                                    , activation=activation 
                                                                    , gpu_count=gpu_count
                                                                    , skip_bn=skip_bn
                                                                  )
            for opt in opt_list:
                # オプティマイザ
                optim = define_model.get_optimizers(opt, decay=0.0)
                lr_metric = my_metric.get_lr_metric(optim)
                # モデルコンパイル
                model.compile(loss=multi_loss.build_masked_loss(K.binary_crossentropy)
                              , optimizer=optim
                              , metrics=['accuracy', 'binary_accuracy', multi_loss.masked_accuracy, lr_metric])
                
                
                model.fit_generator(generator_multi_train
                    , steps_per_epoch=d_cls.train_steps_per_epoch()
                    , epochs=epochs
                    , validation_data=generator_multi_valid
                    , validation_steps=d_cls.valid_steps_per_epoch()
                    , callbacks=cb
                    , verbose=1)
                
# %matplotlib inline
plot_12task_log.plot_results(out_dir, os.path.join(out_dir, 'history.tsv'))
# Out:
# ----- train_ImageDataGenerator -----
# use_mixup: False
# IDG_options: {'horizontal_flip': True, 'vertical_flip': True, 'rotation_range': 60, 'zoom_range': [0.5, 1.9], 'shear_range': 0.2, 'preprocessing_function': <function get_random_eraser.<locals>.eraser at 0x7f308b707ea0>}
#
# ###################################
# ----- model_param -----
# output_dir = output_test/331x331
# img_rows img_cols channels = 331 331 3
# num_classes = 12
# choice_model trainable = ResNet50 all
# FCnum = None
# FCpool = GlobalAveragePooling2D
# pred_kernel_initializer pred_l2_rate = zeros 0.0001
# activation = sigmoid
# gpu_count = 1
# skip_bn = True
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ----- FC_layer -----
# ---- choice_optim = nadam ----
# nadam_lr nadam_schedule_decay beta_1 beta_2 = 0.002 0.004 0.9 0.999
# Epoch 1/3
#  71/692 [==>...........................] - ETA: 15:02 - loss: 2.3068 - task0_pred_loss: 0.2954 - task1_pred_loss: 0.1540 - task2_pred_loss: 0.1320 - task3_pred_loss: 0.1585 - task4_pred_loss: 0.2672 - task5_pred_loss: 0.1468 - task6_pred_loss: 0.0830 - task7_pred_loss: 0.2934 - task8_pred_loss: 0.1186 - task9_pred_loss: 0.1673 - task10_pred_loss: 0.2982 - task11_pred_loss: 0.1925 - task0_pred_acc: 0.6172 - task0_pred_binary_accuracy: 0.6172 - task0_pred_masked_accuracy: 0.8688 - task0_pred_lr: 0.0015 - task1_pred_acc: 0.7597 - task1_pred_binary_accuracy: 0.7597 - task1_pred_masked_accuracy: 0.9553 - task1_pred_lr: 0.0015 - task2_pred_acc: 0.6968 - task2_pred_binary_accuracy: 0.6968 - task2_pred_masked_accuracy: 0.9577 - task2_pred_lr: 0.0015 - task3_pred_acc: 0.5609 - task3_pred_binary_accuracy: 0.5609 - task3_pred_masked_accuracy: 0.9330 - task3_pred_lr: 0.0015 - task4_pred_acc: 0.5733 - task4_pred_binary_accuracy: 0.5733 - task4_pred_masked_accuracy: 0.8734 - task4_pred_lr: 0.0015 - task5_pred_acc: 0.7075 - task5_pred_binary_accuracy: 0.7075 - task5_pred_masked_accuracy: 0.9561 - task5_pred_lr: 0.0015 - task6_pred_acc: 0.6703 - task6_pred_binary_accuracy: 0.6703 - task6_pred_masked_accuracy: 0.9774 - task6_pred_lr: 0.0015 - task7_pred_acc: 0.5128 - task7_pred_binary_accuracy: 0.5128 - task7_pred_masked_accuracy: 0.8379 - task7_pred_lr: 0.0015 - task8_pred_acc: 0.7548 - task8_pred_binary_accuracy: 0.7548 - task8_pred_masked_accuracy: 0.9719 - task8_pred_lr: 0.0015 - task9_pred_acc: 0.6694 - task9_pred_binary_accuracy: 0.6694 - task9_pred_masked_accuracy: 0.9503 - task9_pred_lr: 0.0015 - task10_pred_acc: 0.5095 - task10_pred_binary_accuracy: 0.5095 - task10_pred_masked_accuracy: 0.8275 - task10_pred_lr: 0.0015 - task11_pred_acc: 0.6910 - task11_pred_binary_accuracy: 0.6910 - task11_pred_masked_accuracy: 0.9344 - task11_pred_lr: 0.0015
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2075                     outs = self.train_on_batch(x, y,
#    2076                                                sample_weight=sample_weight,
# -> 2077                                                class_weight=class_weight)
#    2078
#    2079                     if not isinstance(outs, list):
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1795             ins = x + y + sample_weights
#    1796         self._make_train_function()
# -> 1797         outputs = self.train_function(ins)
#    1798         if len(outputs) == 1:
#    1799             return outputs[0]
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/tmp10014/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
